# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from PIL import Image
import cv2
import os

from google.colab.patches import cv2_imshow

import tensorflow as tf
tf.random.set_seed(0)
from tensorflow import keras

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d abdallahalidev/plantvillage-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/abdallahalidev/plantvillage-dataset
# License(s): CC-BY-NC-SA-4.0

# %%
from zipfile import ZipFile
dataset = "/content/plantvillage-dataset.zip"

with ZipFile(dataset, "r") as zip:
  zip.extractall()
  print("The dataset has been extracted")
# Out:
# The dataset has been extracted

# %%
filename = os.listdir("/content/plantvillage dataset/color/Apple___Apple_scab")
print(filename)
print(len(filename))
# Out:
# ['53035d10-9f2b-4c90-ab75-dfde2a9af82f___FREC_Scab 2915.JPG', 'af598e54-dae1-47e5-aefc-0b0a419dfa07___FREC_Scab 3211.JPG', '72317b7f-8162-4454-b6db-c2e6e5455911___FREC_Scab 3088.JPG', '88b51f59-08ed-41fe-8402-69f0964f87fe___FREC_Scab 3299.JPG', 'cf1d9afc-3473-4c97-ae0b-6f2352d9d595___FREC_Scab 3457.JPG', '8edca1d5-7ab9-47b6-bdd0-b61e4a11621e___FREC_Scab 3512.JPG', '40d60cf0-1311-40c7-9e7e-579e74c92027___FREC_Scab 3136.JPG', 'd9a98a38-faa1-47dc-9710-28a86f024a29___FREC_Scab 3490.JPG', 'ef0593e6-f8bc-4501-9c2a-8ee8a6ff33fc___FREC_Scab 3495.JPG', 'bbab7c92-4287-4e69-82b0-5c37fea5897c___FREC_Scab 3017.JPG', '6fb41b7b-d1f0-451c-988a-1083d038acdb___FREC_Scab 3094.JPG', '51929389-451f-4c78-a66b-b644e82a33b6___FREC_Scab 3528.JPG', '62c3478f-3ab0-48df-962f-9d7782ec364d___FREC_Scab 2925.JPG', 'd730c2c9-ac5f-4c4e-b568-2f3e8b43b1a9___FREC_Scab 3074.JPG', '9eab7829-c658-4544-b6ba-f7fb10035aab___FREC_Scab 3382.JPG', '0340dc35-5215-48ab-8db7-06af99fcb358___FREC_Scab 2966.JPG', '4442b558-4db4-4de3-8
# ...

# %%
base_dir = "/content/plantvillage dataset/color"

# %%
img_size = 224
batch_size = 32

# %%
data_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# %%
# Train generator

train_data_generator = data_generator.flow_from_directory(base_dir, target_size=(img_size, img_size), class_mode="categorical", batch_size=batch_size, subset="training")
# Out:
# Found 43456 images belonging to 38 classes.

# %%
# Validation generator

validation_data_generator = data_generator.flow_from_directory(base_dir, target_size=(img_size, img_size), class_mode="categorical", batch_size=batch_size, subset="validation")
# Out:
# Found 10849 images belonging to 38 classes.

# %%
model = keras.Sequential([keras.layers.Conv2D(32, kernel_size=(3,3), activation="relu", input_shape=(224,224,3)),
                          keras.layers.MaxPooling2D(pool_size=(2,2)),

                          keras.layers.Conv2D(64, kernel_size=(3,3), activation="relu"),
                          keras.layers.MaxPooling2D(pool_size=(2,2)),

                          keras.layers.Conv2D(128, kernel_size=(3,3), activation="relu"),
                          keras.layers.MaxPooling2D(pool_size=(2,2)),

                          keras.layers.Flatten(),
                          keras.layers.Dense(256, activation="relu"),
                          keras.layers.Dense(train_data_generator.num_classes, activation="softmax")


                          ])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
model.fit(train_data_generator, validation_data=validation_data_generator, epochs=10)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 104s 71ms/step - accuracy: 0.5780 - loss: 1.5535 - val_accuracy: 0.8607 - val_loss: 0.4502
# Epoch 2/10
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 91s 67ms/step - accuracy: 0.8965 - loss: 0.3256 - val_accuracy: 0.8861 - val_loss: 0.3569
# Epoch 3/10
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 91s 67ms/step - accuracy: 0.9520 - loss: 0.1500 - val_accuracy: 0.8998 - val_loss: 0.3566
# Epoch 4/10
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 91s 67ms/step - accuracy: 0.9697 - loss: 0.0929 - val_accuracy: 0.8905 - val_loss: 0.4279
# Epoch 5/10
# ...

# %%
model.evaluate(validation_data_generator, steps=validation_data_generator.samples//batch_size)
# Out:
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - accuracy: 0.9096 - loss: 0.4437
# [0.44959166646003723, 0.9107669591903687]

# %%
img = "/content/corm maize healthy.jpg"

# %%
# When you use cv2.imread(), OpenCV loads the image in BGR color order,
# but your training images (ImageDataGenerator) are read in RGB mode.
# Thus, at test time your image is seen differently than during training!

# After you convert BGR 2 RGB your predictions becomes more accurate!!!

img = cv2.imread(img)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (224,224))
img_array = np.array(img)
img = np.reshape(img_array, [1,224,224,3])
img = img.astype('float32')/255

prediction = model.predict(img)
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# [[6.2001401e-18 4.7881540e-26 6.1144015e-28 6.4041430e-22 6.7410429e-22
#   3.1412618e-19 1.1369401e-17 2.6865996e-17 1.3742251e-15 2.3309051e-14
#   9.9999988e-01 3.5104030e-20 5.2002451e-20 6.0464660e-20 5.1175108e-21
#   2.1621564e-16 2.8149142e-21 6.3725552e-31 6.9121038e-21 1.6581361e-17
#   1.5097666e-18 4.3835006e-23 5.7118164e-25 4.3954117e-28 2.0098476e-15
#   7.6865220e-08 1.5433345e-21 5.8584952e-26 1.5175596e-21 1.8772998e-20
#   3.6825818e-14 9.5802916e-23 1.2614362e-21 5.7452447e-27 6.9045835e-31
#   6.4822459e-17 2.4903253e-32 1.8601413e-20]]

# %%
print(prediction)
# Out:
# [[6.2001401e-18 4.7881540e-26 6.1144015e-28 6.4041430e-22 6.7410429e-22
#   3.1412618e-19 1.1369401e-17 2.6865996e-17 1.3742251e-15 2.3309051e-14
#   9.9999988e-01 3.5104030e-20 5.2002451e-20 6.0464660e-20 5.1175108e-21
#   2.1621564e-16 2.8149142e-21 6.3725552e-31 6.9121038e-21 1.6581361e-17
#   1.5097666e-18 4.3835006e-23 5.7118164e-25 4.3954117e-28 2.0098476e-15
#   7.6865220e-08 1.5433345e-21 5.8584952e-26 1.5175596e-21 1.8772998e-20
#   3.6825818e-14 9.5802916e-23 1.2614362e-21 5.7452447e-27 6.9045835e-31
#   6.4822459e-17 2.4903253e-32 1.8601413e-20]]

# %%
pred_lables = np.argmax(prediction)

# %%
print(pred_lables)
# Out:
# 10

# %%
aas =  {v:k for k,v in train_data_generator.class_indices.items()}

# %%
aswwq = aas[pred_lables]

# %%
aswwq
# Out:
# 'Corn_(maize)___healthy'
